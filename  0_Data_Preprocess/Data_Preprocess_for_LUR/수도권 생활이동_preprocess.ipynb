# %%
import pandas as pd

df = pd.read_csv('/Users/judetak/Downloads/seoul_trans_admdong3_final_20260331 2.csv', encoding= 'UTF-8')
# Out:
# /var/folders/pk/6tlj8j4n5b90lwc_4d4rr51m0000gn/T/ipykernel_61092/2884756610.py:3: DtypeWarning: Columns (0: o_admdong_cd) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/judetak/Downloads/seoul_trans_admdong3_final_20260331 2.csv', encoding= 'UTF-8')

# %%
df.head()
# Out:
#   o_admdong_cd  d_admdong_cd  st_time_cd  fns_time_cd in_forn_div_nm  \
# 0     11110515      11110515           0            0            내국인
# 1     11110515      11110515           0            0            내국인
# 2     11110515      11110515           0            0          단기외국인
# 3     11110515      11110530           0            0            내국인
# 4     11110515      11110550           0            0            내국인
#
#   forn_citiz_nm  move_trans  move_dist  move_time    cnt   etl_ymd
# 0            한국           7        165          5  28.71  20260331
# 1            한국           9          0         47   2.74  20260331
# 2            기타           7          0         14   7.00  20260331
# 3            한국           7        522         12   1.91  20260331
# 4            한국           8       1868          6   5.71  20260331

# %%
df.size
# Out:
# 84796767

# %%
df[df['move_trans'].isin([3,4,5,8])].size
# Out:
# 47963289
